# %% [markdown]
# <a href="https://colab.research.google.com/github/harshith-118/MachineLearningProjects/blob/main/Credit_Card_Defaulter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.8.0

# %%
dataset = pd.read_excel("default_of_credit_card_clients_0.xlsx")
dataset.tail()
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [5 rows x 25 columns]

# %%
dataset.drop(columns="ID",inplace=True)

# %%
dataset.tail()
# Out:
#        LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month
# 29995     220000    1  ...      1000                           0
# 29996     150000    1  ...         0                           0
# 29997      30000    1  ...      3100                           1
# 29998      80000    1  ...      1804                           1
# 29999      50000    1  ...      1000                           1
#
# [5 rows x 24 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
# ...

# %%
dataset.isna().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
dataset.corr()
# Out:
#                             LIMIT_BAL  ...  default payment next month
# LIMIT_BAL                    1.000000  ...                   -0.153520
# SEX                          0.024755  ...                   -0.039961
# EDUCATION                   -0.219161  ...                    0.028006
# MARRIAGE                    -0.108139  ...                   -0.024339
# AGE                          0.144713  ...                    0.013890
# PAY_0                       -0.170745  ...                    0.396019
# PAY_2                       -0.197136  ...                    0.327093
# PAY_3                       -0.191323  ...                    0.286999
# PAY_4                       -0.180629  ...                    0.269055
# PAY_5                       -0.170045  ...                    0.260850
# PAY_6                       -0.167820  ...                    0.244437
# BILL_AMT1                    0.285430  ...                   -0.019644
# ...

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
  
sns.boxplot(x = 'EDUCATION', y = 'MARRIAGE', data = dataset)

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
train_dataset
# Out:
#        LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month
# 8225       20000    1  ...       644                           0
# 10794      20000    2  ...         0                           0
# 9163      230000    2  ...         0                           0
# 26591     100000    1  ...      2000                           0
# 6631      150000    1  ...      7130                           0
# ...          ...  ...  ...       ...                         ...
# 24308     420000    1  ...      3025                           0
# 6495       50000    2  ...         0                           0
# 4739      230000    2  ...      8618                           0
# 15393     390000    2  ...         0                           0
# 18516     280000    2  ...     12704                           0
#
# [24000 rows x 24 columns]

# %%
test_dataset
# Out:
#        LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month
# 10        200000    2  ...        66                           0
# 13         70000    1  ...         0                           1
# 19        180000    2  ...         0                           0
# 28         50000    2  ...         0                           0
# 40        360000    1  ...      4000                           0
# ...          ...  ...  ...       ...                         ...
# 29977     420000    1  ...      5000                           0
# 29984      30000    1  ...      1000                           0
# 29991     210000    1  ...         0                           1
# 29992      10000    1  ...         0                           0
# 29993     100000    1  ...      2000                           0
#
# [6000 rows x 24 columns]

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('default payment next month')
test_labels = test_features.pop('default payment next month')

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
normalizer.adapt(np.array(train_features))

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()
  plt.grid(True)

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      layers.Dense(256, activation='relu',kernel_initializer='he_normal'),
      layers.Dense(512, activation='relu',kernel_initializer='he_normal'),
      layers.Dense(256, activation='relu',kernel_initializer='he_normal'),
      layers.Dense(2,activation='sigmoid',kernel_initializer='he_normal')
  ])

  model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
  return model

# %%
dnn_model = build_and_compile_model(normalizer)

# %%
# %%time
history = dnn_model.fit(
    train_features,
    train_labels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# CPU times: user 7min 38s, sys: 34.6 s, total: 8min 13s
# Wall time: 5min 19s

# %%
plot_loss(history)

# %%
loss, acc = dnn_model.evaluate(test_features,test_labels, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# Test Accuracy: 0.775

# %%
test_result={}
test_result['Loss Function Value']=loss

# %%
pd.DataFrame(test_result, index=['Sparse Categorical Crossentropy [risky and non-risky]']).T
# Out:
#                 Sparse Categorical Crossentropy [risky and non-risky]
# Accuracy Value                                           0.534749
